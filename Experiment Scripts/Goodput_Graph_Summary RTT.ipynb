# %%
import numpy as npt
import pandas as pd
import matplotlib.pyplot as plt
# from gym import wrappers
# from gym import spaces
import math
import random
import re
import os
import sys
import seaborn as sns

# %%
import os

def functionfilenameandpath(path='./', extension='.em1.pcap'):
    filepaths = []
    filenames = []

    for root, _, files_list in os.walk(path):
        for file_name in files_list:
            if file_name.endswith(extension):
                file_name_path = os.path.join(root, file_name)
                filenames.append(file_name)
                filepaths.append(file_name_path)

    return filenames, filepaths
folderpath="./datatest2"
filenames,filepaths=functionfilenameandpath(folderpath,'em1.pcap')

filepaths.sort()
filenames.sort()
print(filenames)
# Out:
# ['codel_10Mbps_20ms_ecn.em1.pcap', 'codel_10Mbps_20ms_noecn.em1.pcap', 'codel_1Mbps_20ms_ecn.em1.pcap', 'codel_1Mbps_20ms_noecn.em1.pcap', 'fq_codel_10Mbps_20ms_ecn.em1.pcap', 'fq_codel_10Mbps_20ms_noecn.em1.pcap', 'fq_codel_1Mbps_20ms_ecn.em1.pcap', 'fq_codel_1Mbps_20ms_noecn.em1.pcap', 'fq_pie_10Mbps_20ms_ecn.em1.pcap', 'fq_pie_10Mbps_20ms_noecn.em1.pcap', 'fq_pie_1Mbps_20ms_ecn.em1.pcap', 'fq_pie_1Mbps_20ms_noecn.em1.pcap', 'l4s_10Mbps_20ms_ecn.em1.pcap', 'l4s_10Mbps_20ms_noecn.em1.pcap', 'l4s_1Mbps_20ms_ecn.em1.pcap', 'l4s_1Mbps_20ms_noecn.em1.pcap', 'pie_10Mbps_20ms_ecn.em1.pcap', 'pie_10Mbps_20ms_noecn.em1.pcap', 'pie_1Mbps_20ms_ecn.em1.pcap', 'pie_1Mbps_20ms_noecn.em1.pcap']

# %%
pcap_file = filepaths[0]

# %%
import re

def contains_1_or_2(input_string):
    if '2' in input_string:
        return 2
    elif '1' in input_string:
        return 1
    else:
        return 0

# Example usage:
test_string = "abc123xyz"
result = contains_1_or_2(test_string)
print("Result:", result)
# Out:
# Result: 2

# %%
import scapy

# %%
# Read packets from the pcap file
pcap_file = './datatest2/fq_codel_1Mbps_20ms_ecn.em1.pcap'

# %%
# Read packets from the pcap file
pcap_file = './datatest1/fq_pie_1Mbps_20ms_ecn.em1.pcap'

# %%
import dpkt
import socket


# Define the maximum port and window size
def get_tcp_window_scale_option(tcp_options):
    for opt in dpkt.tcp.parse_opts(tcp_options):
        if opt[0] == dpkt.tcp.TCP_OPT_WSCALE:
            scale_factor = int.from_bytes(opt[1], byteorder='big')
            return 2 ** scale_factor
    return 1  # Default scale if option is not present


def analysis_pcap_tcp(pcap_file):
    with open(pcap_file, 'rb') as f:
        pcap = dpkt.pcap.Reader(f)
        tcp_flows = {}
        sender_ip = None

        for timestamp, buf in pcap:
            try:
                # Parse the packet
                eth = dpkt.ethernet.Ethernet(buf)
                # Ensure the packet is an IP packet
                if not isinstance(eth.data, dpkt.ip.IP):
                    continue
                ip = eth.data
                # Ensure the packet is a TCP packet
                if not isinstance(ip.data, dpkt.tcp.TCP):
                    continue
                tcp = ip.data

                # Extract relevant information from the packet
                src_ip = socket.inet_ntoa(ip.src)
                dst_ip = socket.inet_ntoa(ip.dst)

                # Determine if this is the first packet in the conversation to set the sender
                if sender_ip is None and (tcp.flags & dpkt.tcp.TH_SYN):
                    sender_ip = src_ip  # The sender is the one who sends the first SYN
                if sender_ip != dst_ip and sender_ip != src_ip and (tcp.flags & dpkt.tcp.TH_SYN):
                    sender_ip = src_ip  # The sender is the one who sends the first SYN
                # If this packet is not from the sender, ignore it
                if src_ip != sender_ip:
                    continue

                # Extract the source and destination ports
                src_port = tcp.sport
                dst_port = tcp.dport

                # Sort IP addresses and ports to identify flows uniquely irrespective of direction.
                flow_id = (src_ip, src_port, dst_ip, dst_port)

                # Ensure flow is initialized for any TCP packet, adjusting the logic accordingly.
                if flow_id not in tcp_flows:
                    tcp_flows[flow_id] = {
                        'start_time': None, 'end_time': timestamp, 'data_bytes': 0,
                        'transactions': [], 'handshake_complete': False, 'packet_count': 0, 
                        'flow_tuple': flow_id, 'window_scale': 1, 'syn': False, 'fin': False,
                        'initial_rtt': None, 'rtt_estimation': None, 'cwnd_packets': [], 
                        'last_packet_time': None, 'ack_freq': {}, 'seq_numbers': {},   
                        'triple_dup_acks': 0, 'timeouts': 0, 'retransmissions': -1, 'seen_seqs': {},
                    }

                # Get the flow object
                flow = tcp_flows[flow_id]
                flow['end_time'] = timestamp

                # Update the flow information
                if flow['start_time'] is None and tcp.flags & dpkt.tcp.TH_SYN:
                    flow['start_time'] = timestamp  # Set the start time of the flow
                    flow['window_scale'] = get_tcp_window_scale_option(tcp.opts) # Get the window scale option
                if flow['start_time'] is not None:
                    flow['data_bytes'] += len(tcp)
                    flow['packet_count'] += 1
                    
                # Check for handshake completion
                if tcp.flags & dpkt.tcp.TH_SYN and not tcp.flags & dpkt.tcp.TH_ACK:
                    flow['syn'] = True
                if tcp.flags & dpkt.tcp.TH_ACK and flow['syn'] and not flow['handshake_complete']:
                    flow['handshake_complete'] = True

                # Check for flow termination
                if tcp.flags & dpkt.tcp.TH_FIN | dpkt.tcp.TH_RST:
                    flow['fin'] = True
                
                
                # Check for data packets
                if flow['handshake_complete'] and len(tcp.data) > 0:
                    # Add the transaction to the flow if one of first 2
                    if len(flow['transactions']) < 2:
                        flow['transactions'].append((tcp.seq, tcp.ack, tcp.win * flow['window_scale']))

                # Adjusting logic to capture initial RTT and counting packets per RTT
                if tcp.flags & dpkt.tcp.TH_SYN and not flow['initial_rtt']:
                    flow['last_packet_time'] = timestamp  # Mark the time of the SYN packet
                elif tcp.flags & dpkt.tcp.TH_ACK and flow['syn'] and not flow['initial_rtt']:
                    # Assuming this ACK is part of the handshake completion
                    flow['initial_rtt'] = timestamp - flow['last_packet_time']  # Initial RTT estimation
                    flow['rtt_estimation'] = flow['initial_rtt']  # Storing initial RTT as the estimate
                    flow['last_packet_time'] = timestamp  # Resetting for packet counting

                # Logic to count packets per estimated RTT
                if flow['initial_rtt']:
                    time_since_last_packet = timestamp - flow['last_packet_time']
                    if time_since_last_packet < flow['rtt_estimation']:
                        # Still within the same RTT, count the packet
                        if len(flow['cwnd_packets']) == 0:
                            flow['cwnd_packets'].append(1)  # Starting the first count
                        else:
                            flow['cwnd_packets'][-1] += 1  # Increment current RTT's packet count 
                            pass
                    else:
                        # New RTT period, reset packet count
                        if len(flow['cwnd_packets']) < 4:  # Only if we need more CWND sizes
                            flow['cwnd_packets'].append(1)  # Start counting for a new CWND size
                        flow['last_packet_time'] = timestamp  # Resetting for next RTT counting

                if (tcp.flags & dpkt.tcp.TH_ACK) and not (tcp.flags & dpkt.tcp.TH_SYN):
                    ack = tcp.ack
                    # Track ACKs for triple duplicate detection
                    if ack not in flow['ack_freq']:
                        flow['ack_freq'][ack] = 1
                    else:
                        flow['ack_freq'][ack] += 1
                        current_ack_freq = flow['ack_freq'][ack]
                        if current_ack_freq == 4:  # Triple duplicate ACK detected
                            flow['triple_dup_acks'] += 1

                # Track sequence numbers to identify retransmissions
                if tcp.seq not in flow['seq_numbers']:
                    flow['seq_numbers'][tcp.seq] = timestamp
                else:
                    # Check if the packet is a retransmission
                    if timestamp - flow['seq_numbers'][tcp.seq] > 2 * flow['rtt_estimation']: # Timeout threshold
                        flow['timeouts'] += 1

                # Track sequence numbers to detect retransmissions
                seq = tcp.seq
                if flow['handshake_complete'] and seq in flow['seen_seqs'] and flow['seen_seqs'][seq] is True:
                    # If the sequence number has been seen before, it's a retransmission
                    flow['retransmissions'] += 1
                    flow['seen_seqs'][seq] = False
                elif flow['handshake_complete']:
                    # Otherwise, mark the sequence number as seen
                    flow['seen_seqs'][seq] = True

            except Exception as e:
                # Print the error and continue to the next packet
                print(f"Error processing packet: {e}")

    # Output results
    print(f"\nNumber of TCP flows initiated from the sender: {len(tcp_flows)}\n")
    flow_count = 1
    for flow_id, data in tcp_flows.items():
        print(f"Flow {flow_count}:")
        flow_count += 1
        print(flow)
        print(f"  Source IP: {data['flow_tuple'][0]}, Source Port: {data['flow_tuple'][1]} -> Destination IP: {data['flow_tuple'][2]}, Destination Port: {data['flow_tuple'][3]}")
        for i, transaction in enumerate(data['transactions'], 1):
            seq_num, ack_num, rec_win_size = transaction
            print(f"  Transaction {i}: Seq Num: {seq_num}, Ack Num: {ack_num}, Rec Win Size: {rec_win_size}")
        if 'end_time' in data and data['end_time'] is not None:
            duration = data['end_time'] - data['start_time']
            throughput = data['data_bytes'] / duration if duration > 0 else 0
            print(f"  Sender Throughput: {throughput} bytes/sec")
            print(f"  == ({data['data_bytes']} bytes sent in {data['end_time'] - data['start_time']} seconds)")
            print(f"  First 3 Congestion Window Sizes: {data['cwnd_packets'][0:3]}")
            print(f"  Retransmissions due to Triple Duplicate ACKs: {data['retransmissions'] - data['timeouts']}")
            print(f"  Retransmissions due to Timeouts: {data['timeouts']}")
        else:
            print("  Incomplete flow.")
        print()


analysis_pcap_tcp(pcap_file)
# Out:
# Number of TCP flows initiated from the sender: 8
#
# Flow 1:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 34653 -> Destination IP: 172.16.3.2, Destination Port: 5101
#   Transaction 1: Seq Num: 1904095285, Ack Num: 2087077004, Rec Win Size: 65728
#   Transaction 2: Seq Num: 1904095322, Ack Num: 2087077005, Rec Win Size: 65728
#   Sender Throughput: 15.835136255116108 bytes/sec
#   == (969 bytes sent in 61.193032026290894 seconds)
#   First 3 Congestion Window Sizes: [2, 2, 1]
#   Retransmissions due to Triple Duplicate ACKs: 2
#   Retransmissions due to Timeouts: 1
#
# Flow 2:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 18627 -> Destination IP: 172.16.3.2, Destination Port: 5101
#   Transaction 1: Seq Num: 1349918258, Ack Num: 490601963, Rec Win Size: 65728
#   Transaction 2: Seq Num: 1349918295, Ack Num: 490601963, Rec Win Size: 65728
#   Sender Throughput: 29520.622095382067 bytes/sec
#   == (1784549 bytes sent in 60.45092797279358 seconds)
#   First 3 Congestion Window Sizes: [2, 10, 20]
#   Retransmissions due to Triple Duplicate ACKs: 1
#   Retransmissions due to Timeouts: 95
#
# Flow 3:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 22141 -> Destination IP: 172.16.3.2, Destination Port: 5102
#   Transaction 1: Seq Num: 225339592, Ack Num: 1513620653, Rec Win Size: 65728
#   Transaction 2: Seq Num: 225339629, Ack Num: 1513620654, Rec Win Size: 65728
#   Sender Throughput: 16.161163242209735 bytes/sec
#   == (989 bytes sent in 61.19608998298645 seconds)
#   First 3 Congestion Window Sizes: [2, 2, 1]
#   Retransmissions due to Triple Duplicate ACKs: 1
#   Retransmissions due to Timeouts: 2
#
# Flow 4:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 24820 -> Destination IP: 172.16.3.2, Destination Port: 5102
#   Transaction 1: Seq Num: 4022538025, Ack Num: 3170945868, Rec Win Size: 65728
#   Transaction 2: Seq Num: 4022538062, Ack Num: 3170945868, Rec Win Size: 65728
#   Sender Throughput: 15617.12923729659 bytes/sec
#   == (948909 bytes sent in 60.760782957077026 seconds)
#   First 3 Congestion Window Sizes: [12, 20, 3]
#   Retransmissions due to Triple Duplicate ACKs: -6
#   Retransmissions due to Timeouts: 66
#
# Flow 5:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 39485 -> Destination IP: 172.16.3.2, Destination Port: 5103
#   Transaction 1: Seq Num: 1025714972, Ack Num: 1910238856, Rec Win Size: 65728
#   Transaction 2: Seq Num: 1025715009, Ack Num: 1910238857, Rec Win Size: 65728
#   Sender Throughput: 15.486688722141364 bytes/sec
#   == (975 bytes sent in 62.95729303359985 seconds)
#   First 3 Congestion Window Sizes: [2, 2, 1]
#   Retransmissions due to Triple Duplicate ACKs: 0
#   Retransmissions due to Timeouts: 3
#
# Flow 6:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 28871 -> Destination IP: 172.16.3.2, Destination Port: 5103
#   Transaction 1: Seq Num: 2028507551, Ack Num: 1884151, Rec Win Size: 65728
#   Transaction 2: Seq Num: 2028507588, Ack Num: 1884151, Rec Win Size: 65728
#   Sender Throughput: 23259.647700780617 bytes/sec
#   == (1437584 bytes sent in 61.80592322349548 seconds)
#   First 3 Congestion Window Sizes: [2, 10, 12]
#   Retransmissions due to Triple Duplicate ACKs: -4
#   Retransmissions due to Timeouts: 124
#
# Flow 7:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 52081 -> Destination IP: 172.16.3.2, Destination Port: 5104
#   Transaction 1: Seq Num: 3120816859, Ack Num: 2146560393, Rec Win Size: 65728
#   Transaction 2: Seq Num: 3120816896, Ack Num: 2146560394, Rec Win Size: 65728
#   Sender Throughput: 15.487159337478667 bytes/sec
#   == (985 bytes sent in 63.60107612609863 seconds)
#   First 3 Congestion Window Sizes: [4, 2, 1]
#   Retransmissions due to Triple Duplicate ACKs: 1
#   Retransmissions due to Timeouts: 2
#
# Flow 8:
# {'start_time': 1720556987.301447, 'end_time': 1720557050.902523, 'data_bytes': 985, 'transactions': [(3120816859, 2146560393, 65728), (3120816896, 2146560394, 65728)], 'handshake_complete': True, 'packet_count': 15, 'flow_tuple': ('172.16.1.2', 52081, '172.16.3.2', 5104), 'window_scale': 64, 'syn': True, 'fin': True, 'initial_rtt': 0.1764521598815918, 'rtt_estimation': 0.1764521598815918, 'cwnd_packets': [4, 2, 1, 5], 'last_packet_time': 1720557050.902523, 'ack_freq': {2146560393: 2, 2146560394: 2, 2146560395: 2, 2146560397: 2, 2146560398: 2, 2146560734: 1, 2146560735: 2, 2146560736: 1}, 'seq_numbers': {3120816858: 1720556987.301447, 3120816859: 1720556987.477899, 3120816896: 1720556987.60822, 3120816900: 1720556987.608588, 3120817024: 1720556988.149585, 3120817025: 1720557050.637552, 3120817029: 1720557050.637978, 3120817343: 1720557050.763642, 3120817344: 1720557050.765714, 3120817345: 1720557050.902523}, 'triple_dup_acks': 0, 'timeouts': 2, 'retransmissions': 3, 'seen_seqs': {3120816859: False, 3120816896: True, 3120816900: True, 3120817024: False, 3120817025: True, 3120817029: True, 3120817343: False, 3120817344: True, 3120817345: True}}
#   Source IP: 172.16.1.2, Source Port: 39643 -> Destination IP: 172.16.3.2, Destination Port: 5104
#   Transaction 1: Seq Num: 4060394264, Ack Num: 1464454049, Rec Win Size: 65728
#   Transaction 2: Seq Num: 4060394264, Ack Num: 1464454049, Rec Win Size: 65728
#   Sender Throughput: 26370.497317691294 bytes/sec
#   == (1644566 bytes sent in 62.36385989189148 seconds)
#   First 3 Congestion Window Sizes: [2, 1, 1]
#   Retransmissions due to Triple Duplicate ACKs: 1
#   Retransmissions due to Timeouts: 76

# %%
seq_timestamps
# Out:
# {(b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   53370,
#   5101,
#   2557952802): 1720558587.382831,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   53370,
#   5101,
#   2557952803): 1720558587.499762,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   53370,
#   5101,
#   2557952840): 1720558587.627354,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   53370,
#   5101,
#   2557952844): 1720558587.628156,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081842531): 1720558587.747767,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081842532): 1720558587.88009,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081842569): 1720558588.011118,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081844017): 1720558588.011573,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081845465): 1720558588.01197,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081846913): 1720558588.012309,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081848361): 1720558588.012627,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081849809): 1720558588.012957,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081851257): 1720558588.013283,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081852705): 1720558588.013602,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081854153): 1720558588.013919,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081855601): 1720558588.038089,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081857049): 1720558588.243951,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081858497): 1720558588.245043,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081859945): 1720558588.247283,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081861393): 1720558588.24861,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081862841): 1720558588.259028,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081864289): 1720558588.26014,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081865737): 1720558588.261361,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081867185): 1720558588.262178,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081868633): 1720558588.307473,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081870081): 1720558588.310199,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081871529): 1720558588.311912,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081872977): 1720558588.313407,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081874425): 1720558588.318614,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081875873): 1720558588.319606,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081877321): 1720558588.492836,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081878769): 1720558588.589216,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081880217): 1720558588.644037,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081881665): 1720558588.657881,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081883113): 1720558588.658967,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081884561): 1720558588.69682,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081886009): 1720558588.697089,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081887457): 1720558588.747773,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081888905): 1720558588.748139,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081890353): 1720558588.748546,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081891801): 1720558588.797848,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081893249): 1720558588.798871,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081894697): 1720558588.800199,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081896145): 1720558588.801151,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081897593): 1720558588.850145,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081899041): 1720558588.851159,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081900489): 1720558588.908669,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081901937): 1720558588.910699,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081903385): 1720558588.999618,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081904833): 1720558589.001005,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081906281): 1720558589.05046,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081907729): 1720558589.051085,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081909177): 1720558589.051674,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081910625): 1720558589.052127,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081912073): 1720558589.052504,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081913521): 1720558589.108235,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081914969): 1720558589.109407,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081916417): 1720558589.11047,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081917865): 1720558589.183722,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081919313): 1720558589.263822,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081920761): 1720558589.352276,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081922209): 1720558589.539531,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081923657): 1720558589.540926,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081925105): 1720558589.668042,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081926553): 1720558589.704825,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081928001): 1720558589.705092,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081929449): 1720558589.842183,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081930897): 1720558589.844173,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081932345): 1720558589.84546,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081933793): 1720558589.847441,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081935241): 1720558589.869352,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081936689): 1720558590.016854,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081938137): 1720558590.016938,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081939585): 1720558590.017233,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081941033): 1720558590.017318,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081942481): 1720558590.017395,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081943929): 1720558590.108002,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081945377): 1720558590.200173,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081946825): 1720558590.200486,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081948273): 1720558590.208817,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081949721): 1720558590.209171,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081951169): 1720558590.291427,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081952617): 1720558590.293982,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081954065): 1720558590.295269,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081955513): 1720558590.362579,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081956961): 1720558590.364532,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081958409): 1720558590.388192,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081959857): 1720558590.389613,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081961305): 1720558590.465708,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081962753): 1720558590.465953,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081964201): 1720558590.488284,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081965649): 1720558590.488536,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081967097): 1720558590.527769,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081968545): 1720558590.528017,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081969993): 1720558590.577636,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081971441): 1720558590.5779,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081972889): 1720558590.626349,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081974337): 1720558590.626604,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081975785): 1720558590.679319,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081977233): 1720558590.680652,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081978681): 1720558590.681905,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081980129): 1720558590.739493,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081981577): 1720558590.740833,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081983025): 1720558590.775885,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081984473): 1720558590.776129,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081985921): 1720558590.828413,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081987369): 1720558590.829131,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081988817): 1720558590.876874,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081990265): 1720558590.877398,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081991713): 1720558590.87789,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081993161): 1720558590.878385,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081994609): 1720558590.878884,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081996057): 1720558590.879397,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081997505): 1720558590.928123,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3081998953): 1720558590.929081,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082000401): 1720558591.125388,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082001849): 1720558591.156621,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082003297): 1720558591.156871,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082004745): 1720558591.157105,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082006193): 1720558591.184208,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082007641): 1720558591.184466,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082009089): 1720558591.184728,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082010537): 1720558591.184972,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082011985): 1720558591.185219,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082013433): 1720558591.185452,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082014881): 1720558591.185686,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082016329): 1720558591.185922,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082017777): 1720558591.186279,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082019225): 1720558591.257865,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082020673): 1720558591.398294,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082022121): 1720558591.429217,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082023569): 1720558591.429461,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082025017): 1720558591.455508,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082026465): 1720558591.455781,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082027913): 1720558591.45604,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082029361): 1720558591.456427,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082030809): 1720558591.456695,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082032257): 1720558591.456959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082033705): 1720558591.457217,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082035153): 1720558591.457451,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082036601): 1720558591.457783,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082038049): 1720558591.45802,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082039497): 1720558591.458248,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082040945): 1720558591.458476,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082042393): 1720558591.458705,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082043841): 1720558591.458947,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082045289): 1720558591.459208,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082046737): 1720558591.459448,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082048185): 1720558591.459677,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082049633): 1720558591.497654,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082051081): 1720558591.530417,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082052529): 1720558591.612708,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082053977): 1720558591.61417,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082055425): 1720558591.887287,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082056873): 1720558591.888651,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082058321): 1720558591.88998,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082059769): 1720558591.891538,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082061217): 1720558591.892651,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082062665): 1720558591.893642,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082064113): 1720558591.894524,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082065561): 1720558591.895209,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082067009): 1720558591.895859,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082068457): 1720558591.896828,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082069905): 1720558591.897498,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082071353): 1720558591.898178,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082072801): 1720558591.898988,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082074249): 1720558591.899435,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082075697): 1720558591.899885,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082077145): 1720558591.900334,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082078593): 1720558591.903553,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082080041): 1720558591.939234,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082081489): 1720558591.960321,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082082937): 1720558591.962267,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082084385): 1720558592.041971,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082085833): 1720558592.042347,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082087281): 1720558592.042796,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082088729): 1720558592.070473,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082090177): 1720558592.075937,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082091625): 1720558592.12555,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082093073): 1720558592.127546,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082094521): 1720558592.175708,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082095969): 1720558592.322736,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082097417): 1720558592.456174,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082098865): 1720558592.486487,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082100313): 1720558592.486758,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082101761): 1720558592.487076,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082103209): 1720558592.487342,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082104657): 1720558592.487745,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082106105): 1720558592.488623,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082107553): 1720558592.489042,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082109001): 1720558592.489724,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082110449): 1720558592.49058,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082111897): 1720558592.491113,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082113345): 1720558592.491999,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082114793): 1720558592.492702,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082116241): 1720558592.493154,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082117689): 1720558592.493615,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082119137): 1720558592.493961,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082120585): 1720558592.494191,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082122033): 1720558592.494427,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082123481): 1720558592.518313,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082124929): 1720558592.519199,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082126377): 1720558592.540802,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082127825): 1720558592.568715,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082129273): 1720558592.569868,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082130721): 1720558592.609219,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082132169): 1720558592.610537,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082133617): 1720558592.639242,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082135065): 1720558592.639961,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082136513): 1720558592.668544,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082137961): 1720558592.668802,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082139409): 1720558592.709423,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082140857): 1720558592.711085,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082142305): 1720558592.712794,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082143753): 1720558592.739192,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082145201): 1720558592.740585,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082146649): 1720558592.742235,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082148097): 1720558592.770108,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082149545): 1720558592.771469,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082150993): 1720558592.798377,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082152441): 1720558592.79974,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082153889): 1720558592.817267,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082155337): 1720558592.818309,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082156785): 1720558592.888989,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082158233): 1720558592.890308,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082159681): 1720558593.109052,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082161129): 1720558593.236801,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082162577): 1720558593.318439,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082164025): 1720558593.375193,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082165473): 1720558593.377098,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082166921): 1720558593.447323,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082168369): 1720558593.447595,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082169817): 1720558593.447841,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082171265): 1720558593.448073,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082172713): 1720558593.479303,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082174161): 1720558593.530339,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082175609): 1720558593.531699,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082177057): 1720558593.532979,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082178505): 1720558593.53835,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082179953): 1720558593.539678,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082181401): 1720558593.579113,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082182849): 1720558593.580433,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082184297): 1720558593.588838,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082185745): 1720558593.590146,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082187193): 1720558593.618714,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082188641): 1720558593.619621,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082190089): 1720558593.639751,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082191537): 1720558593.640693,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082192985): 1720558593.677035,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082194433): 1720558593.679787,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082195881): 1720558593.703516,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082197329): 1720558593.70454,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082198777): 1720558593.749946,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082200225): 1720558593.751184,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082201673): 1720558593.787362,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082203121): 1720558593.78929,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082204569): 1720558593.808339,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082206017): 1720558593.80959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082207465): 1720558593.815726,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082208913): 1720558593.816717,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082210361): 1720558593.857201,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082211809): 1720558593.858272,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082213257): 1720558593.8925,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082214705): 1720558593.893805,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082216153): 1720558593.921614,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082217601): 1720558593.923617,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082219049): 1720558593.963187,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082220497): 1720558593.964538,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082221945): 1720558593.970647,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082223393): 1720558594.238407,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082224841): 1720558594.239437,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082226289): 1720558594.327567,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082227737): 1720558594.380926,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082229185): 1720558594.408644,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082230633): 1720558594.486622,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082232081): 1720558594.487163,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082233529): 1720558594.519447,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082234977): 1720558594.520144,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082236425): 1720558594.565675,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082237873): 1720558594.567704,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082239321): 1720558594.589018,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082240769): 1720558594.640893,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082242217): 1720558594.641397,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082243665): 1720558594.643028,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082245113): 1720558594.643449,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082246561): 1720558594.669667,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082248009): 1720558594.671414,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082249457): 1720558594.67959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082250905): 1720558594.680507,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082252353): 1720558594.709372,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082253801): 1720558594.711307,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082255249): 1720558594.748022,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082256697): 1720558594.749985,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082258145): 1720558594.778657,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082259593): 1720558594.779166,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082261041): 1720558594.77959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082262489): 1720558594.780001,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082263937): 1720558594.81265,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082265385): 1720558594.814142,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082266833): 1720558594.858801,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082268281): 1720558594.860702,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082269729): 1720558594.888623,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082271177): 1720558594.889994,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082272625): 1720558594.913932,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082274073): 1720558594.916093,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082275521): 1720558594.955418,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082276969): 1720558594.957338,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082278417): 1720558594.999359,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082279865): 1720558595.000672,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082281313): 1720558595.027422,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082282761): 1720558595.028081,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082284209): 1720558595.068374,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082285657): 1720558595.069506,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082287105): 1720558595.112909,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082288553): 1720558595.290078,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082290001): 1720558595.44698,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082291449): 1720558595.447839,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082292897): 1720558595.448962,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082294345): 1720558595.509873,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082295793): 1720558595.568854,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082297241): 1720558595.570242,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082298689): 1720558595.577133,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082300137): 1720558595.617672,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082301585): 1720558595.618689,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082303033): 1720558595.669294,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082304481): 1720558595.671205,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082305929): 1720558595.692142,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082307377): 1720558595.719946,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082308825): 1720558595.721346,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082310273): 1720558595.750367,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082311721): 1720558595.751698,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082313169): 1720558595.783175,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082314617): 1720558595.784596,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082316065): 1720558595.798846,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082317513): 1720558595.800058,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082318961): 1720558595.844633,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082320409): 1720558595.8473,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082321857): 1720558595.857237,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082323305): 1720558595.858543,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082324753): 1720558595.897582,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082326201): 1720558595.899535,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082327649): 1720558595.940294,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082329097): 1720558595.941624,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082330545): 1720558595.957738,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082331993): 1720558595.958053,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082333441): 1720558595.958333,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082334889): 1720558595.958594,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082336337): 1720558595.979158,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082337785): 1720558595.98047,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082339233): 1720558596.008091,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082340681): 1720558596.010207,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082342129): 1720558596.073776,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082343577): 1720558596.07502,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082345025): 1720558596.1072,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082346473): 1720558596.108607,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082347921): 1720558596.167615,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082349369): 1720558596.168939,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082350817): 1720558596.246937,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082352265): 1720558596.247658,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082353713): 1720558596.376848,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082355161): 1720558596.518963,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082356609): 1720558596.528411,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082358057): 1720558596.530392,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082359505): 1720558596.597474,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082360953): 1720558596.659628,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082362401): 1720558596.660968,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082363849): 1720558596.687251,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082365297): 1720558596.709158,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082366745): 1720558596.738994,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082368193): 1720558596.740354,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082369641): 1720558596.79049,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082371089): 1720558596.791738,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082372537): 1720558596.818475,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082373985): 1720558596.819625,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082375433): 1720558596.821016,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082376881): 1720558596.821732,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082378329): 1720558596.889732,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082379777): 1720558596.891626,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082381225): 1720558596.893629,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082382673): 1720558596.91839,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082384121): 1720558596.952672,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082385569): 1720558596.954564,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082387017): 1720558596.957356,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082388465): 1720558596.977331,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082389913): 1720558596.978866,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082391361): 1720558597.008286,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082392809): 1720558597.009943,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082394257): 1720558597.039774,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082395705): 1720558597.063283,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082397153): 1720558597.065246,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082398601): 1720558597.067134,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082400049): 1720558597.099214,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082401497): 1720558597.099595,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082402945): 1720558597.100048,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082404393): 1720558597.100533,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082405841): 1720558597.157903,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082407289): 1720558597.158156,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082408737): 1720558597.184489,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082410185): 1720558597.184833,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082411633): 1720558597.235312,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082413081): 1720558597.235563,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082414529): 1720558597.327506,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082415977): 1720558597.327755,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082417425): 1720558597.374959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   50005,
#   5102,
#   3008715495): 1720558597.379311,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082418873): 1720558597.488706,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   50005,
#   5102,
#   3008715496): 1720558597.4957,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082420321): 1720558597.582695,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082421769): 1720558597.637411,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082423217): 1720558597.637661,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   50005,
#   5102,
#   3008715533): 1720558597.63808,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   50005,
#   5102,
#   3008715537): 1720558597.638162,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082424665): 1720558597.69617,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082426113): 1720558597.745057,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082427561): 1720558597.745306,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082429009): 1720558597.777827,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509295044): 1720558597.778246,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082430457): 1720558597.805443,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082431905): 1720558597.855195,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082433353): 1720558597.855398,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082434801): 1720558597.85571,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082436249): 1720558597.886483,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082437697): 1720558597.886734,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082439145): 1720558597.90504,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082440593): 1720558597.905119,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509295045): 1720558597.905499,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082442041): 1720558597.957256,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082443489): 1720558597.957505,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082444937): 1720558597.994983,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082446385): 1720558597.995235,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082447833): 1720558598.01471,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082449281): 1720558598.014956,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509295082): 1720558598.028678,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509296530): 1720558598.029003,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509297978): 1720558598.029331,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509299426): 1720558598.029652,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509300874): 1720558598.029968,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509302322): 1720558598.030283,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509303770): 1720558598.030607,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509305218): 1720558598.030923,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509306666): 1720558598.03124,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082450729): 1720558598.055704,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082452177): 1720558598.055946,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509308114): 1720558598.083644,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082453625): 1720558598.087342,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082455073): 1720558598.087705,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082456521): 1720558598.12498,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082457969): 1720558598.125227,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082459417): 1720558598.170876,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082460865): 1720558598.171639,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082462313): 1720558598.225432,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082463761): 1720558598.257818,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082465209): 1720558598.259051,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082466657): 1720558598.318033,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082468105): 1720558598.360827,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082469553): 1720558598.361367,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509309562): 1720558598.36667,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509311010): 1720558598.367059,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082471001): 1720558598.423249,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509312458): 1720558598.423505,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509313906): 1720558598.423745,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509315354): 1720558598.423975,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509316802): 1720558598.424221,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082472449): 1720558598.496352,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082473897): 1720558598.49662,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082475345): 1720558598.547416,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509318250): 1720558598.59049,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082476793): 1720558598.59059,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082478241): 1720558598.707288,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082479689): 1720558598.707651,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082481137): 1720558598.814962,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509319698): 1720558598.846248,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509321146): 1720558598.900579,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509322594): 1720558598.90096,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082482585): 1720558598.944105,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509324042): 1720558599.066453,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082484033): 1720558599.096518,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082485481): 1720558599.199495,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509325490): 1720558599.225163,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082486929): 1720558599.270341,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082488377): 1720558599.358628,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082489825): 1720558599.359184,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082491273): 1720558599.385506,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082492721): 1720558599.386786,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509326938): 1720558599.42482,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509328386): 1720558599.425066,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082494169): 1720558599.461269,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082495617): 1720558599.476237,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082497065): 1720558599.476496,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082498513): 1720558599.52496,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082499961): 1720558599.525211,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082501409): 1720558599.569332,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509329834): 1720558599.589402,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509331282): 1720558599.591081,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509332730): 1720558599.592661,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
# ...
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509567306): 1720558607.478465,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509568754): 1720558607.478929,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082759153): 1720558607.487596,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082760601): 1720558607.488512,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   62772,
#   5103,
#   3523386806): 1720558607.49559,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082762049): 1720558607.558444,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082763497): 1720558607.629102,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082764945): 1720558607.629994,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082766393): 1720558607.633581,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   62772,
#   5103,
#   3523386843): 1720558607.634621,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   62772,
#   5103,
#   3523386847): 1720558607.634831,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082767841): 1720558607.668318,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082769289): 1720558607.669581,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509570202): 1720558607.696013,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082770737): 1720558607.770069,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082772185): 1720558607.771245,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201378601): 1720558607.774111,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082773633): 1720558607.866743,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082775081): 1720558607.868413,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082776529): 1720558607.896303,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082777977): 1720558607.898243,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201378602): 1720558607.918389,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082779425): 1720558608.04157,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082780873): 1720558608.042622,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082782321): 1720558608.106155,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082783769): 1720558608.108058,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201378639): 1720558608.149792,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201380087): 1720558608.151698,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201381535): 1720558608.15354,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201382983): 1720558608.154534,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201384431): 1720558608.155485,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201385879): 1720558608.15675,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201387327): 1720558608.157705,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201388775): 1720558608.158335,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201390223): 1720558608.159175,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201391671): 1720558608.159804,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082785217): 1720558608.188966,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082786665): 1720558608.189809,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082788113): 1720558608.190598,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082789561): 1720558608.190903,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509571650): 1720558608.19121,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509573098): 1720558608.191446,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509574546): 1720558608.191658,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509575994): 1720558608.191868,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509577442): 1720558608.192078,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509578890): 1720558608.192287,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509580338): 1720558608.192499,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509581786): 1720558608.192708,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509583234): 1720558608.192916,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509584682): 1720558608.193125,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509586130): 1720558608.193334,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509587578): 1720558608.193543,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509589026): 1720558608.193754,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509590474): 1720558608.193966,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509591922): 1720558608.1942,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509593370): 1720558608.194412,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509594818): 1720558608.194627,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509596266): 1720558608.195705,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509597714): 1720558608.19591,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509599162): 1720558608.196052,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509600610): 1720558608.196187,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509602058): 1720558608.196321,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509603506): 1720558608.196676,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509604954): 1720558608.196815,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509606402): 1720558608.196959,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509607850): 1720558608.197109,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509609298): 1720558608.197251,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082791009): 1720558608.227558,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509610746): 1720558608.228277,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509612194): 1720558608.228917,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082792457): 1720558608.279282,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082793905): 1720558608.279784,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509613642): 1720558608.281472,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509615090): 1720558608.281901,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509616538): 1720558608.358988,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082795353): 1720558608.37707,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082796801): 1720558608.378096,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509617986): 1720558608.434758,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082798249): 1720558608.43501,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509619434): 1720558608.487704,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509620882): 1720558608.488165,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082799697): 1720558608.490423,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509622330): 1720558608.577301,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509623778): 1720558608.57862,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201393119): 1720558608.615311,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201394567): 1720558608.615682,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509625226): 1720558608.627697,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509626674): 1720558608.62877,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509628122): 1720558608.687045,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082801145): 1720558608.717063,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509629570): 1720558608.760673,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509631018): 1720558608.762042,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082802593): 1720558608.797232,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509632466): 1720558608.818712,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509633914): 1720558608.819196,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201396015): 1720558608.967212,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201397463): 1720558608.968395,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082804041): 1720558609.057839,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201398911): 1720558609.058293,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082805489): 1720558609.170359,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201400359): 1720558609.171203,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201401807): 1720558609.314624,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201403255): 1720558609.314871,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201404703): 1720558609.315107,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201406151): 1720558609.31534,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082806937): 1720558609.315578,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082808385): 1720558609.315927,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201407599): 1720558609.428453,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201409047): 1720558609.428961,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082809833): 1720558609.508292,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201410495): 1720558609.545995,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201411943): 1720558609.547735,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082811281): 1720558609.569872,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201413391): 1720558609.679363,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509635362): 1720558609.929349,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082812729): 1720558610.000046,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201414839): 1720558610.041003,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082814177): 1720558610.096372,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082815625): 1720558610.0983,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082817073): 1720558610.145101,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201416287): 1720558610.208501,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082818521): 1720558610.21535,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509636810): 1720558610.241543,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082819969): 1720558610.316728,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082821417): 1720558610.318117,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509638258): 1720558610.34875,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082822865): 1720558610.350599,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082824313): 1720558610.351551,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201417735): 1720558610.416921,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201419183): 1720558610.417421,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509639706): 1720558610.434974,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082825761): 1720558610.446753,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082827209): 1720558610.447352,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509641154): 1720558610.482449,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509642602): 1720558610.51597,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509644050): 1720558610.518078,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082828657): 1720558610.549122,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082830105): 1720558610.55053,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082831553): 1720558610.555185,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082833001): 1720558610.556875,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082834449): 1720558610.596635,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509645498): 1720558610.60533,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509646946): 1720558610.606025,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201420631): 1720558610.625414,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201422079): 1720558610.626237,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201423527): 1720558610.627369,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201424975): 1720558610.627994,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082835897): 1720558610.659419,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509648394): 1720558610.687609,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509649842): 1720558610.688978,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509651290): 1720558610.729422,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509652738): 1720558610.730736,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082837345): 1720558610.76136,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082838793): 1720558610.762764,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509654186): 1720558610.817244,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509655634): 1720558610.818566,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201426423): 1720558610.867054,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   65475,
#   5103,
#   2201427871): 1720558610.869173,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509657082): 1720558610.892115,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509658530): 1720558610.893159,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082840241): 1720558610.902869,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082841689): 1720558610.903112,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509659978): 1720558610.970255,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   22668,
#   5102,
#   509661426): 1720558610.971433,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082843137): 1720558610.972015,
#  (b'\xac\x10\x01\x02',
#   b'\xac\x10\x03\x02',
#   17149,
#   5101,
#   3082844585): 1720558610.972434,
#  ...}

# %%
rtts
# Out:
# {5101: [], 5102: [], 5103: [], 5104: []}
